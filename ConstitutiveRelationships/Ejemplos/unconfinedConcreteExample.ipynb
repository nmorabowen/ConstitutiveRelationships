# %%
# importamos dependencias

import ConstitutiveRelationships as cr
from baseUnits import kgf, cm
from plotApeConfig import set_default_plot_params, blueAPE
set_default_plot_params()
import matplotlib.pyplot as plt

# %%
fc210=cr.uniaxialUnconfinedConcrete('fc210', 210*kgf/cm**2, plot=True)

# %%
fc210=cr.uniaxialUnconfinedConcrete('fc210', 210*kgf/cm**2)
fc240=cr.uniaxialUnconfinedConcrete('fc240', 240*kgf/cm**2, color=blueAPE)
fc280=cr.uniaxialUnconfinedConcrete('fc280', 280*kgf/cm**2, color='red')
fc350=cr.uniaxialUnconfinedConcrete('fc350', 350*kgf/cm**2, color='grey')
fc400=cr.uniaxialUnconfinedConcrete('fc400', 400*kgf/cm**2, color='darkolivegreen')

fig, ax = plt.subplots(figsize=(10,5))
fc210.plot(ax=ax)
fc240.plot(ax=ax)
fc280.plot(ax=ax)
fc350.plot(ax=ax)
fc400.plot(ax=ax)
